# %%
import requests
from pprint import pprint

# %%
BASE_URL = 'https://nominatim.openstreetmap.org/search?format=json'

# %%
postcode = 'G42 9AY'

response = requests.get(f"{BASE_URL}&postalcode={postcode}")
data = response.json()
pprint(data)
# Out:
# [{'boundingbox': ['55.66523', '55.98523', '-4.4132', '-4.0932'],
#   'class': 'place',
#   'display_name': 'Glasgow City, Alba / Scotland, G42 9AY, United Kingdom',
#   'importance': 0.325,
#   'lat': '55.82523',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'https://osm.org/copyright',
#   'lon': '-4.2532',
#   'place_id': 300504406,
#   'type': 'postcode'}]

# %%
latitude = data[0].get('lat')
longitude = data[0].get('lon')
print(latitude, longitude)

bbox = data[0].get('boundingbox')
print(bbox)
# Out:
# 55.82523 -4.2532
# ['55.66523', '55.98523', '-4.4132', '-4.0932']

# %%
zipcode = '2601'

response = requests.get(f"{BASE_URL}&postalcode={zipcode}")
response.json()
# Out:
# [{'place_id': 301447052,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'boundingbox': ['47.6194369', '47.9394369', '18.9704672', '19.2904672'],
#   'lat': '47.7794369',
#   'lon': '19.1304672',
#   'display_name': 'Vác, Váci járás, Pest megye, Közép-Magyarország, 2601, Magyarország',
#   'class': 'place',
#   'type': 'postcode',
#   'importance': 0.33499999999999996},
#  {'place_id': 299223513,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 13555585,
#   'boundingbox': ['47.8719496', '47.9198343', '16.2189075', '16.2931997'],
#   'lat': '47.89580775',
#   'lon': '16.245415489000663',
#   'display_name': 'Niederösterreich, 2601, Österreich',
#   'class': 'boundary',
#   'type': 'postal_code',
#   'importance': 0.33499999999999996},
#  {'place_id': 299522007,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'boundingbox': ['47.729903212892',
#    '48.049903212892',
#    '16.091558210086',
#    '16.411558210086'],
#   'lat': '47.88990321289181',
#   'lon': '16.251558210085946',
#   'display_name': 'Gemeinde Sollenau, Bezirk Wiener Neustadt, Niederösterreich, 2601, Österreich',
#   'class': 'place',
#   'type': 'postcode',
#   'importance': 0.33499999999999996},
#  {'place_id': 299026970,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 11661816,
#   'boundingbox': ['-35.2968846', '-35.2653718', '149.0976289', '149.1375885'],
#   'lat': '-35.2813927',
#   'lon': '149.1227649735631',
#   'display_name': 'Australian Capital Territory, 2601, Australia',
#   'class': 'boundary',
#   'type': 'postal_code',
#   'importance': 0.33499999999999996},
#  {'place_id': 299524595,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'boundingbox': ['-35.4566843', '-35.1366843', '148.9395058', '149.2595058'],
#   'lat': '-35.2966843',
#   'lon': '149.0995058',
#   'display_name': 'Yarralumla, District of Canberra Central, Australian Capital Territory, 2601, Australia',
#   'class': 'place',
#   'type': 'postcode',
#   'importance': 0.33499999999999996},
#  {'place_id': 302013036,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'boundingbox': ['16.295011619205',
#    '16.615011619205',
#    '120.43615051126',
#    '120.75615051126'],
#   'lat': '16.455011619205298',
#   'lon': '120.59615051125827',
#   'display_name': 'La Trinidad, Benguet, Cordillera Administrative Region, 2601, Philippines',
#   'class': 'place',
#   'type': 'postcode',
#   'importance': 0.33499999999999996}]

# %%
response = requests.get(f"{BASE_URL}&postalcode={zipcode}&country=italia")
data = response.json()

# %%
latitude2 = 45.33059985
longitude2 = 9.774886999999994

# %%
import folium

# create tuples representing our location
location = float(latitude), float(longitude)
location2 = float(latitude2), float(longitude2)

# center the map at Amsterdam
amsterdam = (52.3676, 4.9041)

# create a Folium map centred at the above location
m = folium.Map(location=amsterdam, zoom_start=4, width=800, height=400)

# add markers at the locations
folium.Marker(location, popup="The postcode brought me here").add_to(m)
folium.Marker(location2, popup="The postcode brought me here").add_to(m)

# refer to the map to display it in Jupyter/Colab notebooks
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a9edab1de312f4dbc68a037a14c2b2e {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a9edab1de312f4dbc68a037a14c2b2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0a9edab1de312f4dbc68a037a14c2b2e = L.map(
#                 &quot;map_0a9edab1de312f4dbc68a037a14c2b2e&quot;,
#                 {
#                     center: [52.3676, 4.9041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_738793937dbab498ac27929f1f9d9be6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a9edab1de312f4dbc68a037a14c2b2e);
#
#
#             var marker_13f0afea3bd90c65506400244c37520a = L.marker(
#                 [55.82523, -4.2532],
#                 {}
#             ).addTo(map_0a9edab1de312f4dbc68a037a14c2b2e);
#
#
#         var popup_19ca336a2b800959c421e56358a0650a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2d29ff0a96ddc6452c250263efe36df8 = $(`&lt;div id=&quot;html_2d29ff0a96ddc6452c250263efe36df8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_19ca336a2b800959c421e56358a0650a.setContent(html_2d29ff0a96ddc6452c250263efe36df8);
#
#
#         marker_13f0afea3bd90c65506400244c37520a.bindPopup(popup_19ca336a2b800959c421e56358a0650a)
#         ;
#
#
#
#
#             var marker_5650751c94552b2fbecf477e9404ade3 = L.marker(
#                 [45.33059985, 9.774886999999994],
#                 {}
#             ).addTo(map_0a9edab1de312f4dbc68a037a14c2b2e);
#
#
#         var popup_218b154bfea55cb48e67ad87bc7eba59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e76e1eafb0f157ce7f5c1114026ff91f = $(`&lt;div id=&quot;html_e76e1eafb0f157ce7f5c1114026ff91f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_218b154bfea55cb48e67ad87bc7eba59.setContent(html_e76e1eafb0f157ce7f5c1114026ff91f);
#
#
#         marker_5650751c94552b2fbecf477e9404ade3.bindPopup(popup_218b154bfea55cb48e67ad87bc7eba59)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
midpoint_gen = ((x+y)/2 for x,y in zip(location, location2))

# convert generator to a tuple representing lat/longitude of the midpoint
midpoint = tuple(midpoint_gen)

print(location)
print(location2)
print(midpoint)
# Out:
# (55.82523, -4.2532)
# (45.33059985, 9.774886999999994)
# (50.577914925, 2.7608434999999973)

# %%
import folium

# create Folium map
m = folium.Map(location=midpoint, zoom_start=4, width=800, height=400)

# add marker at the locations
folium.Marker(location, popup="The postcode brought me here").add_to(m)
folium.Marker(location2, popup="The postcode brought me here").add_to(m)
folium.Marker(midpoint, popup="Middle!").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87394ff420eab78a15da82028572a9bb {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87394ff420eab78a15da82028572a9bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_87394ff420eab78a15da82028572a9bb = L.map(
#                 &quot;map_87394ff420eab78a15da82028572a9bb&quot;,
#                 {
#                     center: [50.577914925, 2.7608434999999973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cafadb6085e90f0c5eb78d7455b202f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87394ff420eab78a15da82028572a9bb);
#
#
#             var marker_c82b4a95950c23df784f058c3ea44734 = L.marker(
#                 [55.82523, -4.2532],
#                 {}
#             ).addTo(map_87394ff420eab78a15da82028572a9bb);
#
#
#         var popup_370dbc8ede4312ee15e926bec108e1c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f911fa631a35ebca6fb767b226622647 = $(`&lt;div id=&quot;html_f911fa631a35ebca6fb767b226622647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_370dbc8ede4312ee15e926bec108e1c0.setContent(html_f911fa631a35ebca6fb767b226622647);
#
#
#         marker_c82b4a95950c23df784f058c3ea44734.bindPopup(popup_370dbc8ede4312ee15e926bec108e1c0)
#         ;
#
#
#
#
#             var marker_50893b9d24bac182b80bf8f4f1ed5e16 = L.marker(
#                 [45.33059985, 9.774886999999994],
#                 {}
#             ).addTo(map_87394ff420eab78a15da82028572a9bb);
#
#
#         var popup_1a7638f6349108d08fa7454afc82778a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_02517df1faab38bbdc40df9e0a02546a = $(`&lt;div id=&quot;html_02517df1faab38bbdc40df9e0a02546a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_1a7638f6349108d08fa7454afc82778a.setContent(html_02517df1faab38bbdc40df9e0a02546a);
#
#
#         marker_50893b9d24bac182b80bf8f4f1ed5e16.bindPopup(popup_1a7638f6349108d08fa7454afc82778a)
#         ;
#
#
#
#
#             var marker_46c681d859e2bf263bcb08c04d2aa512 = L.marker(
#                 [50.577914925, 2.7608434999999973],
#                 {}
#             ).addTo(map_87394ff420eab78a15da82028572a9bb);
#
#
#         var popup_6a81f9a393f3b0651b452cfcee3abad8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0a45617efa33dd5117e9e0ce222df54c = $(`&lt;div id=&quot;html_0a45617efa33dd5117e9e0ce222df54c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Middle!&lt;/div&gt;`)[0];
#             popup_6a81f9a393f3b0651b452cfcee3abad8.setContent(html_0a45617efa33dd5117e9e0ce222df54c);
#
#
#         marker_46c681d859e2bf263bcb08c04d2aa512.bindPopup(popup_6a81f9a393f3b0651b452cfcee3abad8)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from geopy.distance import distance

km = distance(location, location2)
miles = distance(location, location2).miles

print("Distance between postcodes:")
print(f"{km}")
print(f"{miles} miles")
# Out:
# Distance between postcodes:
# 1527.1529950917281 km
# 948.9288772889624 miles

# %%
import folium

# create a Folium map centred at the above location
m = folium.Map(location=midpoint, zoom_start=4, width=800, height=400)

# add marker at the locations
folium.Marker(location, popup="The postcode brought me here").add_to(m)
folium.Marker(location2, popup="The postcode brought me here").add_to(m)

# add line between points
folium.PolyLine((location,location2)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6099cec76a6b6d80013c9cdde167ad06 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6099cec76a6b6d80013c9cdde167ad06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6099cec76a6b6d80013c9cdde167ad06 = L.map(
#                 &quot;map_6099cec76a6b6d80013c9cdde167ad06&quot;,
#                 {
#                     center: [50.577914925, 2.7608434999999973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39189055cac2fc930d6a6cd525403608 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6099cec76a6b6d80013c9cdde167ad06);
#
#
#             var marker_e63a50a074930195c91916fa8c89ca4f = L.marker(
#                 [55.82523, -4.2532],
#                 {}
#             ).addTo(map_6099cec76a6b6d80013c9cdde167ad06);
#
#
#         var popup_a4639b9bdd7e2507ba1dfa8a50c26c1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_970efc60eca20a3c70525de00dc73972 = $(`&lt;div id=&quot;html_970efc60eca20a3c70525de00dc73972&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_a4639b9bdd7e2507ba1dfa8a50c26c1a.setContent(html_970efc60eca20a3c70525de00dc73972);
#
#
#         marker_e63a50a074930195c91916fa8c89ca4f.bindPopup(popup_a4639b9bdd7e2507ba1dfa8a50c26c1a)
#         ;
#
#
#
#
#             var marker_cdcd57eb1955a1c190f82c0136e40664 = L.marker(
#                 [45.33059985, 9.774886999999994],
#                 {}
#             ).addTo(map_6099cec76a6b6d80013c9cdde167ad06);
#
#
#         var popup_a1c966a20e2994e710a70d21e4e8dcdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_156d815a2548172c34273dcbf6bff8c7 = $(`&lt;div id=&quot;html_156d815a2548172c34273dcbf6bff8c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The postcode brought me here&lt;/div&gt;`)[0];
#             popup_a1c966a20e2994e710a70d21e4e8dcdd.setContent(html_156d815a2548172c34273dcbf6bff8c7);
#
#
#         marker_cdcd57eb1955a1c190f82c0136e40664.bindPopup(popup_a1c966a20e2994e710a70d21e4e8dcdd)
#         ;
#
#
#
#
#             var poly_line_19f14dd804b4f8fecf3f78823bc58225 = L.polyline(
#                 [[55.82523, -4.2532], [45.33059985, 9.774886999999994]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6099cec76a6b6d80013c9cdde167ad06);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#reference as an example https://github.com/bugbytes-io/notebooks/blob/main/urban-analytics-and-gis/OSM%20API%2C%20Folium%20and%20Geopy.ipynb
